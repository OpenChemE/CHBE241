# %% [markdown]
# # Non-Ideal Gas Laws
#
# ## Learning Objectives
#
# By the end of this section you should be able to:
#
# 1. Understand why most gases dont behave ideally.
# 2. Use equations of the state for non-ideal gases.
# 3. Use the compressability factor.
#
# ## Introduction
#
# Before this class you most likely have used the **ideal gas law**, $ P V = n R T $, but this equation of state is not very accurate in describing gases in the real world. This is because the **ideal gas law** assumes that gas particiles are infinitisemal points of mass and that these points of mass do not interact with each other. This is a major flaw in the ideal gas law and causes the ideal gas law to be close to the true when pressures are very low  and if the gases were noble gases, esspacially Helium.
#
# That is why equations of state for **non-ideal gases** are crucial for calculating how **real gases**. In this section we will focus on the **compressiblility factors** to correct the ideal gas law and the **viral equation**, the **Van der Walls equation**, and the **Soave-Redlich-Kwong equation**.
#
# ## Overview
#
# ### Equations of the State for Non-Ideal Gases
#
# **Critical temperature**, $T_c$ and **critical pressure**, $P_c$ is the the temperature and pressure of a species at its critical point. These two properties often tell us how well or poorly the **ideal gas law** is for describing the species.
#
# #### The Viral Equation of State
#
# The **viral equation of state** is an expression of the quintity $P \hat{V} / R T $ as a power series in the inverse of specific volume:
#
# $$ \frac{P \hat{V}}{R T} = 1 + \frac{B}{\hat{V}} + \frac{B}{\hat{V}^2} + \frac{B}{\hat{V}^3} + ... $$
#
# Where B, C, and D are the second, third, and fourth virial coefficents respectively. These coefficients are functions of temerature. As of right now, estimating the coefficients beyond B is very difficult so we use a truncated version:
#
# $$ \frac{P \hat{V}}{R T} = 1 + \frac{B}{\hat{V}}$$
#
# To solve the **viral equation of state** we must:
#
# 1. look up the **critical temperature**, $T_c$, the **critical pressure**, $P_c$, and the **Pitzer acentric factor**, $ \omega $. **Pitzer acentric factor** is a constant that reflects the geometry and polarity of a molecule.
# 2. Calculate the **reduced temperature**, $T_r = T / T_c$.
# 3. Estimate B using: $$ $$ $$ B_0 = 0.083 - \frac{0.422}{T^{1.6}_r} $$ $$ $$ $$ B_1 = 0.139 - \frac{0.172}{T^{4.2}_r} $$ $$ $$ $$ B = \frac{R T_c}{P_c} (B_0 + \omega B_1) $$ $$ $$
# 4. Substitute B back into the **viral equation of state**.
#
# #### Van der Waals  Equation of State
#
# The **Van der Waals equation of state** is the first **cubic equations of state**. Cubic equations of state are equations that when expanded are third-order equations for specific volume. The equation is:
#
# $$ P = \frac{R T}{ \hat{V} - b} - \frac{a}{\hat{V}}$$
#
# where
#
# $$ a = \frac{27 R^2 T^2_c}{64 P_c} $$
#
# $$ b = \frac{R T_c}{8 P_c} $$
#
# #### Soave–Redlich–Kwong Equation of State
#
# The **Soave–Redlich–Kwong** (SRK) equation of state is more complex yet are remarkably robust in describing a variety of systems. The equation is:
#
# $$ P = \frac{R T}{ \hat{V} - b} - \frac{\alpha a}{\hat{V} (\hat{V} + b)}$$
#
# where
#
# $$ a = 0.42747 \frac{(R T_c)^2}{P_C} $$
#
# $$ b = 0 08664 \frac{R T_c}{P_c} $$
#
# $$ \alpha = (1 + m ( 1 - \sqrt{T_r}))^2 $$
#
# $$ T_r = \frac{T}{T_c} $$
#
# $$ m = 0.48508 + 1.55171 \omega - 0.1561 \omega^2 $$
#
#
# ### Compressability Factor
#
# The **compressibility factor** of a gas is defined as:
#
# $$ Z = \frac{ P \hat{V} }{R T} $$
#
# When $ Z = 1 $, the gas behaves ideally. The amount $ Z $ differs from 1 is a measurement of how non-ideal the gas is.
#
# A method used to estimate $Z$, since every type of gas has diffrent $Z$ factors at the same pressure and tempresure, is:
#
# 1. Look up the **critical temperature**, $T_c$, and **critical pressure**, $P_c$, of the species.
# 2. Calculate the **reduced temperature**, $T_r = \frac{T}{T_c}$ and **reduced pressure**, $P_r = \frac{P}{P_c}$.
# 3. Look yp the values of Z on a **generalized compressibility chart**, which plots $Z$ versus $P_r$.
#
# This metbhod of estimating $Z$ is the empirical **law of corresponding states**. The reduced temperature and pressure provide a measure of the gas's proximity to its critical state. The closer $T_r$ and $P_r$ are to 1, the closer the gas is to  its critial state. This suggests that a plot of $Z$ verses $T_r$ and $P_r$ will be apporximately the same for all substances. This type of plot, shown below, is called a **generalized compressibility chart**.
#
# <img src="../figures/Module-4/Compressability_chart.png" style= "height:400px">
#
# Each line represents a diffrent $T_r$ while $P_r$ is the x-axis. The y value of intersection between the the $T_r$ and $P_r$ is the compressibility factor.
