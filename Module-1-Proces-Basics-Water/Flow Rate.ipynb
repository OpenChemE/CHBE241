# %% [markdown]
# # Flow Rate

# %% [markdown]
# ## Introduction
# Almost every process involves the movement of material from one point to another. The movement of material is present between process units, production facilities, and transportation depots. The rate at which materials are transported is the flow rate.

# %% [markdown]
# ## Overview

# %% [markdown]
# ### Mass Flow Rate
# Mass flow rate is the measurement of mass per unit time (mass/time). This flowrate is usually denoted by this character $ \dot{m} $ where $ \dot{m} = \frac{ kg }{s} $. Since mass must be conserved, the input masses of a process must equal the output masses, unless there is accumulation. Therefore, mass flowrate is a very useful tool in solving material balances.

# %% [markdown]
# ### Molar Flow Rate
# Molar flow rate is the measurement of moles per unit time (mole/time). This flowrate is usually denoted by this character $ \dot{n} $ where $ \dot{n} = \frac{ moles }{s} $. Since the total number of moles of each element must be conserved, it is useful in solving both reactive and non reactive problems.

# %% [markdown]
# ### Volumetric Flow Rate
# Volumetric flow rate is the measurement of volume per unit time (volume/time) This flow rate is usually denoted by this character $ \dot{V} $, where $ \dot{V} = \frac{ m^3 }{s} $. Although volume is nearly conserved for solids and liquids, it is not for gases. For example if a gas is flowing through a nozzle, the mass flow rate will not change but the gas will compress or expand.
#
# ![](../figures/Module-1/Nozzle.jpg)
#
# Since mass flow rate is more useful, but volumetric flow rate is easier to measure, we need to be able to convert from one to the other. Therefore, we use density.
#
# $$ \rho = \frac{m}{V} = \frac{\dot{m}}{\dot{V}} = \frac{\frac{kg}{s}}{\frac{m^3}{s}} = \frac{kg}{m^3} $$
#
# Now, if we have density and volumetric flow rate, we can solve for mass flow rate.

# %% [markdown]
# ### Flow Rate Measurement
# Flow rates are measured by a device called a flowmeter. This device provides a continuous reading of the flow rate in the line. Two commonly used flowmeters are rotameters
#
# ![](../figures/Module-1/Rotameter.jpg)
#
# and orifice meters
#
# ![](../figures/Module-1/Orifice_meter.jpg)
#
# The rotameter is a tapered vertical tube containing a small ball (the black dot in the image). The larger the flow rate, the higher the ball rises due to the increased friction force.
#
# ![](../figures/Module-1/Sphere.jpg)
#
# The orifice meter is an obstruction in the flow channel which causes a pressure drop. The magnitude of the pressure drop dictates the flow rate. The larger the pressure drop, the larger the flow rate. The pressure drop is measured by a manometer.

# %% [markdown]
# ### Manometer
# Manometers are one of the most commonly used tools in measuring pressure drops. This is done by measuring the heights of the different fluids in the manometer. ![](../figures/Module-1/Manometer.jpg)
#
# Writing and equation the expressions for the pressures at points (a) and (b) in the figure shown above, we get the general manometer equation:
#
# $$ \mathbf{P}_1 + \mathbf{\rho}_1 g \mathbf{d}_1 =  \mathbf{P}_2 + \mathbf{\rho}_2 g \mathbf{d}_2 + \mathbf{\rho}_f g h \quad \text{(General Manometer Equation)} $$
#
# If the densities of fluids 1 and 2 are the same, the equation simplifies to:
#
# $$ \mathbf{P}_1 - \mathbf{P}_2 =  (\mathbf{\rho}_f - \rho) g h \quad \text{(Differential Manometer Equation)} $$
#
# If fluids 1 and 2 are gases, the equation simplifies further to:
#
# $$ \mathbf{P}_1 - \mathbf{P}_2 =  \mathbf{\rho}_f  g h \quad \text{(Manometer Formula for Gases)} $$

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### Question
# A differential manometer is used to measure the drop-in pressure between two points in a process line containing water. The specific gravity of the manometer fluid is 1.05. The measured levels in each arm are shown below. Calculate the pressure drop in pascals
#
# ![](../figures/Module-1/Problem_statement.jpg)

# %% [markdown]
# ### Solution

# %%
#Declare all know varibles

rho = 1000  # kg/m^3
rho_f = 1050 # kg/m^3
g = 9.81 # m/s^2
h = 0.382 - 0.374 # m

#Solve for pressure drop using Differential Manometer Equation

P_drop = (rho_f-rho)*g*h

#Print Results

print("The pressure drop is measured to be ", P_drop, "Pa")
# Out:
# The pressure drop is measured to be  3.9240000000000035 Pa

# %% [markdown]
# As you can see the value we get is not exactly 3.924 Pa due to rounding error by the computer, but if you take significant figures into account the final answer is $ \mathbf{P}_1 - \mathbf{P}_2 = 3.92 Pa $
